# %% [markdown]
# 1. what exactly is []?
# [] represents a list, so any data types can be placed into a list; if it does not have any data type, then it is an empty list

# %%
spam = [2,4,6,8,10]

# %%
#2 
spam.insert(2,"hello")

# %%
spam
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %%
spam = ['a','b','c','d']

# %%
#3. 
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
#4 spam[-1]=['d']
spam[-1]
# Out:
# 'd'

# %%
#5 spam[:2]=['a','b']
spam[:2]
# Out:
# ['a', 'b']

# %%
bacon = [3.14,'cat',11,'cat',True]

# %%
#6 answer: 1
bacon.index('cat')
# Out:
# 1

# %%
#7 it adds 99 to the end of the list
bacon.append(99) #did it twice
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99, 99]

# %%
#8 it removes the first occurence of 'cat'
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99, 99]

# %% [markdown]
# #9 What are the list concatenation and list replication operators?
#  answer: + or *

# %% [markdown]
# #10 What is difference between the list methods append() and insert()?
# in append you can add objects to end of list whereas insert function, you can specify index of object

# %% [markdown]
# #11 What are the two methods for removing items from a list?
# .remove or .pop

# %% [markdown]
# #12 Describe how list values and string values are identical.
# list values contain elements in the list, and strings are similar as they are an ordered arrangement of characters

# %% [markdown]
# 13. What's the difference between tuples and lists?
# tuples are immmutable while lists are mutable

# %%
# 14. How do you type a tuple value that only contains the integer 42?
g = (42,) #trailing comma

# %%
type(g)
# Out:
# tuple

# %%
#15. How do you get a list value's tuple form? How do you get a tuple values list form?
#you get it by list() and tuple() functions
list(g)
# Out:
# [42]

# %%
(tuple(list(g)))
# Out:
# (42,)

# %% [markdown]
# #16 variables that contain lists may not necessary be lists themselves but they contain nested lists

# %% [markdown]
# # 17. How do you distinguish between copy.copy() and copy.deepcopy()?
# copy.deepcopy() will duplicate other lists inside the lists while copy.copy() while not - NOT SURE ABOUT THIS

# %%
list_1 = [[234,234,"sanchu"],[213312,"kumar"],"this","is","this",]

# %%
import copy
copy.copy(list_1)
# Out:
# [[234, 234, 'sanchu'], [213312, 'kumar'], 'this', 'is', 'this']

# %%
from copy import deepcopy
copy.deepcopy(list_1)
# Out:
# [[234, 234, 'sanchu'], [213312, 'kumar'], 'this', 'is', 'this']
